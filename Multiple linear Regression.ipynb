# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('housing.csv')
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
data.isnull().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %%
data.fillna(data['total_bedrooms'].mean(),inplace=True)

# %%
data.isnull().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# ocean_proximity       0
# dtype: int64

# %%
#correlation 
data.drop('ocean_proximity',axis=1).corr()['total_rooms']
# Out:
# longitude             0.044568
# latitude             -0.036100
# housing_median_age   -0.361262
# total_rooms           1.000000
# total_bedrooms        0.927253
# population            0.857126
# households            0.918484
# median_income         0.198050
# median_house_value    0.134153
# Name: total_rooms, dtype: float64

# %%
data.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'ocean_proximity'],
#       dtype='object')

# %%
data.drop('ocean_proximity',axis=1,inplace=True)

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
data.reindex(labels=['total_rooms','population','households','total_bedrooms'])
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
import matplotlib.pyplot as plt
plt.scatter(data['total_rooms'],data['total_bedrooms'])

# %%
plt.scatter(data['population'],data['total_bedrooms'])

# %%
plt.scatter(data['households'],data['total_bedrooms'])

# %%
cols=['total_rooms', 'population', 'households']
x=data[cols]
y=data['total_bedrooms']

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
x_train.shape
# Out:
# (16512, 3)

# %%
model=LinearRegression().fit(x_train,y_train)

# %%
model2=LinearRegression().fit(x,y)

# %%
y_pred=model.predict(x_train)
y_pred
y_pred2=model2.predict(x)

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error
mean_absolute_error(y_pred,y_train)
mean_squared_error(y_pred,y_train)
# Out:
# 7628.23965650396

# %%
predictions_df = pd.DataFrame({'Population': data['population'],
                               'Households': data['households'],
                               'Total Rooms': data['total_rooms'],
                               'Bedrooms': data['total_bedrooms'],
                               'Predictions':y_pred2})
predictions_df
# Out:
#        Population  Households  Total Rooms  Bedrooms  Predictions
# 0           322.0       126.0        880.0     129.0   150.305758
# 1          2401.0      1138.0       7099.0    1106.0  1291.235935
# 2           496.0       177.0       1467.0     190.0   217.005702
# 3           558.0       219.0       1274.0     235.0   246.253759
# 4           565.0       259.0       1627.0     280.0   298.290309
# ...           ...         ...          ...       ...          ...
# 20635       845.0       330.0       1665.0     374.0   357.279069
# 20636       356.0       114.0        697.0     150.0   130.288505
# 20637      1007.0       433.0       2254.0     485.0   473.177067
# 20638       741.0       349.0       1860.0     409.0   386.639967
# 20639      1387.0       530.0       2785.0     616.0   573.916568
#
# [20640 rows x 5 columns]

# %%
def get_predictions(model,x):
    (n,p_minus_one)=x.shape
    p=p_minus_one+1
    new_x=np.ones(shape=(n,p))
    new_x[:,1:]=x
    return np.dot(new_x,model)

# %%
test_model=np.array([1,2,3,4])
get_predictions(test_model,x_train)
# Out:
# array([ 1949., 11006.,  7975., ...,  6547.,  9279.,  6607.])

# %%
predictions_df['test prediction']=get_predictions(test_model,x)
predictions_df
# Out:
#        Population  Households  Total Rooms  Bedrooms  Predictions  \
# 0           322.0       126.0        880.0     129.0   150.305758
# 1          2401.0      1138.0       7099.0    1106.0  1291.235935
# 2           496.0       177.0       1467.0     190.0   217.005702
# 3           558.0       219.0       1274.0     235.0   246.253759
# 4           565.0       259.0       1627.0     280.0   298.290309
# ...           ...         ...          ...       ...          ...
# 20635       845.0       330.0       1665.0     374.0   357.279069
# 20636       356.0       114.0        697.0     150.0   130.288505
# 20637      1007.0       433.0       2254.0     485.0   473.177067
# 20638       741.0       349.0       1860.0     409.0   386.639967
# 20639      1387.0       530.0       2785.0     616.0   573.916568
#
#        test prediction
# 0               3231.0
# 1              25954.0
# 2               5131.0
# 3               5099.0
# 4               5986.0
# ...                ...
# ...

# %%
from numpy.linalg import inv
def get_best_model(model,x):
    
    n=x.shape[0]
    p_minus_one=x.shape[1]
    p=p_minus_one+1
    new_x=np.ones(shape=(n,p))
    new_x[:,1:]=x
    return np.dot(np.dot(inv(np.dot(new_x.T,new_x)),new_x.T),y)

# %%
best_model=get_best_model(y,x)
predictions_df['best Prediction']=get_predictions(best_model,x)
predictions_df
# Out:
#        Population  Households  Total Rooms  Bedrooms  Predictions  \
# 0           322.0       126.0        880.0     129.0   150.305758
# 1          2401.0      1138.0       7099.0    1106.0  1291.235935
# 2           496.0       177.0       1467.0     190.0   217.005702
# 3           558.0       219.0       1274.0     235.0   246.253759
# 4           565.0       259.0       1627.0     280.0   298.290309
# ...           ...         ...          ...       ...          ...
# 20635       845.0       330.0       1665.0     374.0   357.279069
# 20636       356.0       114.0        697.0     150.0   130.288505
# 20637      1007.0       433.0       2254.0     485.0   473.177067
# 20638       741.0       349.0       1860.0     409.0   386.639967
# 20639      1387.0       530.0       2785.0     616.0   573.916568
#
#        test prediction  best Prediction
# 0               3231.0       150.305758
# 1              25954.0      1291.235935
# 2               5131.0       217.005702
# ...

# %%
x.shape[1]
# Out:
# 3
